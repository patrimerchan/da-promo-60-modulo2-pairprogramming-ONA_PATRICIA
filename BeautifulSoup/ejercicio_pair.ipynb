# %%
from bs4 import BeautifulSoup
import requests
# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# %%
url = "https://auctionet.com/en/search/29-sculptures-bronzes?order=bid_desc"

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.content
# Out:
# b'<!DOCTYPE html><html class="env-production" data-controller="product-analytics" lang="en"><head><meta charset="utf-8" /><meta content="696ecad7ad01e221bbcec187d930a9df2af59fa6" name="revision" /><meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport" /><meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="LerZj7VW8_l8B3Q7v9ju-Bj27NF748coW-KHbPfOOF-7PWJcdmSMrdVRPCiF-YjMolQNxJKj1p_p7tiYeVuzOw" /><meta content="Art \xe2\x80\x93 For every style and budget \xe2\x80\x93 New auctions every day" name="title" /><meta content="The market\xe2\x80\x99s largest range of modern and antique sculptures. Explore our thousands of online auctions. Secure payment options and safe deliveries." name="description" /><meta content="Auctionet" property="og:site_name" /><meta content="https://images.auctionet.com/uploads/res_1x_item_list_presentation_89c3d9bc6c.jpg" property="og:image" /><meta name="apple-itunes-app" content="app-id=7624379
# ...

# %%
sopa_esculturas = BeautifulSoup(res.content, "html.parser")

# %%
# Extraer: 
# nombres de las esculturas
# precio actual, 
# dias que lleva de subasta
# pujas

# %%
sopa_esculturas.find_all("span")
# Out:
# [<span aria-hidden="true" class="svg"><span class="svg__auctionet-logotype"><svg fill="#000000" viewbox="0 0 456 78" xmlns="http://www.w3.org/2000/svg">
#  <path d="M216.304 6.73133C216.304 3.01353 213.29 -0.00011102 209.572 -0.00011102C205.854 -0.00011102 202.841 3.01353 202.841 6.73133C202.841 10.4491 205.854 13.4628 209.572 13.4628C213.29 13.4628 216.304 10.4491 216.304 6.73133Z"></path>
# ...

# %%
sopa_esculturas.find_all("p")
# Out:
# [<p>The Sculptures category covers a large variety of 3D works of art, including statues, statuettes, busts, herms and other works of a purely abstract nature. Many are cast in bronze or other metals, while others are scuplted in contemporary materials.</p>,
#  <p><a class="button-as-link js-presentation-long-text-toggle" data-text-off="Hide text" data-text-on="Read more" href="#">Read more</a></p>,
#  <p>The Sculptures category covers a large variety of 3D works of art, including statues, statuettes, busts, herms and other works of a purely abstract nature. Many are cast in bronze or other metals, others have been sculpted from earthenware or stoneware clays, glass, plaster or contemporary materials.<br/>
#  The most sought-after items at auction include Classicist bronzes and modern pieces as well as garden sculptures and artistic works in large formats.<br/>
# ...

# %%
sopa_esculturas.find_all("span", class_="test-item-title")
# Out:
# []

# %%
sopa_esculturas.find_all("span", class_="item-thumb__highlight")
# Out:
# []

# %%
sopa_esculturas.find_all("div")
# Out:
# [<div class="site-header__main"><div class="width-container"><div class="site-header__inner"><div class="site-header__top"><div class="site-header__logo"><a href="/en"><span aria-hidden="true" class="svg"><span class="svg__auctionet-logotype"><svg fill="#000000" viewbox="0 0 456 78" xmlns="http://www.w3.org/2000/svg">
#  <path d="M216.304 6.73133C216.304 3.01353 213.29 -0.00011102 209.572 -0.00011102C205.854 -0.00011102 202.841 3.01353 202.841 6.73133C202.841 10.4491 205.854 13.4628 209.572 13.4628C213.29 13.4628 216.304 10.4491 216.304 6.73133Z"></path>
# ...

# %%
sopa_esculturas.find_all("div", class_="item-thumbs item-thumbs--marginless-on-small-displays item-thumbs--vertical-4")
# Out:
# []

# %%
sopa_esculturas.find_all("div", id="results")[0].find_all("div")
# Out:
# [<div class="test-search-results"><div class="search-page__sort-and-pagination hide-in-apps"><div class="search-page__sort-and-pagination__sort test-search-sort"><form accept-charset="UTF-8" action="/en/search/29-sculptures-bronzes" class="search-page__sort-container form form--no-margin" data-controller="turbo-get-form" method="get"><label class="search-page__sort-and-pagination__sort-label search-page__sort-container__label" for="order">Sort by</label> <select class="search-page__sort-container__select" data-controller="auto-submit-on-change" id="order" name="order"><option value="bids_count_asc">Fewest bids</option>
#  <option value="bids_count_desc">Most bids</option>
#  <option value="bid_asc">Lowest bid</option>
#  <option selected="selected" value="bid_desc">Highest bid</option>
#  <option value="bid_on">Last bid on</option>
#  <option value="end_asc_active">Ending soonest</option>
#  <option value="estimate_asc">Lowest estimate</option>
# ...

# %%
sopa_esculturas.find_all("div", id="results")[0].find_all("article")
# Out:
# []
